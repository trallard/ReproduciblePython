# %% [markdown]
# # Creating the exploratory data analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the data

# %%
wine = pd.read_csv('../data/raw/winemag-data-130k-v2.csv')
wine.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# ## Explore the dataset
#
# Getting a basic description of the data.

# %%
wine.describe(include ='all', ).T
# Out:
#                         count  unique  \
# Unnamed: 0             129971     NaN
# country                129908      43
# description            129971  119955
# designation             92506   37979
# points                 129971     NaN
# price                  120975     NaN
# province               129908     425
# region_1               108724    1229
# region_2                50511      17
# taster_name            103727      19
# taster_twitter_handle   98758      15
# title                  129971  118840
# variety                129970     707
# winery                 129971   16757
#
#                                                                      top  \
# Unnamed: 0                                                           NaN
# country                                                               US
# description            Seductively tart in lemon pith, cranberry and ...
# designation                                                      Reserve
# points                                                               NaN
# price                                                                NaN
# province                                                      California
# region_1                                                     Napa Valley
# region_2                                                   Central Coast
# taster_name                                                   Roger Voss
# taster_twitter_handle                                         @vossroger
# title                  Gloria Ferrer NV Sonoma Brut Sparkling (Sonoma...
# variety                                                       Pinot Noir
# winery                                                Wines & Winemakers
#
#                         freq     mean      std  min      25%    50%      75%  \
# Unnamed: 0               NaN    64985  37519.5    0  32492.5  64985  97477.5
# country                54504      NaN      NaN  NaN      NaN    NaN      NaN
# description                3      NaN      NaN  NaN      NaN    NaN      NaN
# designation             2009      NaN      NaN  NaN      NaN    NaN      NaN
# points                   NaN  88.4471  3.03973   80       86     88       91
# price                    NaN  35.3634  41.0222    4       17     25       42
# province               36247      NaN      NaN  NaN      NaN    NaN      NaN
# region_1                4480      NaN      NaN  NaN      NaN    NaN      NaN
# region_2               11065      NaN      NaN  NaN      NaN    NaN      NaN
# taster_name            25514      NaN      NaN  NaN      NaN    NaN      NaN
# taster_twitter_handle  25514      NaN      NaN  NaN      NaN    NaN      NaN
# title                     11      NaN      NaN  NaN      NaN    NaN      NaN
# variety                13272      NaN      NaN  NaN      NaN    NaN      NaN
# winery                   222      NaN      NaN  NaN      NaN    NaN      NaN
#
#                           max
# Unnamed: 0             129970
# country                   NaN
# description               NaN
# designation               NaN
# points                    100
# price                    3300
# province                  NaN
# region_1                  NaN
# region_2                  NaN
# taster_name               NaN
# taster_twitter_handle     NaN
# title                     NaN
# variety                   NaN
# winery                    NaN

# %% [markdown]
# Grouping per country and points to analyse the mean price of the wines

# %%
cnt = wine.groupby(['country','points'])['price'].agg(['count','min','max','mean']).sort_values(by = 'mean',ascending = False)[:10]
cnt.reset_index(inplace=True)
cnt.style.background_gradient(cmap='PuBu',high=0.5)
# Out:
# <style  type="text/css" >
#     #T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col1 {
#             background-color:  #d7d6e9;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col3 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col4 {
#             background-color:  #e9e5f1;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col5 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col1 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col2 {
#             background-color:  #f1ebf4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col3 {
#             background-color:  #f1ebf4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col4 {
#             background-color:  #88b1d4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col5 {
#             background-color:  #69a5cc;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col1 {
#             background-color:  #8bb2d4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col2 {
#             background-color:  #fdf5fa;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col3 {
#             background-color:  #d4d4e8;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col4 {
#             background-color:  #e1dfed;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col5 {
#             background-color:  #b1c2de;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row3_col1 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row3_col2 {
#             background-color:  #fdf5fa;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row3_col3 {
#             background-color:  #a8bedc;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row3_col4 {
#             background-color:  #f2ecf5;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row3_col5 {
#             background-color:  #bfc9e1;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row4_col1 {
#             background-color:  #8bb2d4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row4_col2 {
#             background-color:  #fbf4f9;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row4_col3 {
#             background-color:  #f0eaf4;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row4_col4 {
#             background-color:  #e7e3f0;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row4_col5 {
#             background-color:  #d4d4e8;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row5_col1 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row5_col2 {
#             background-color:  #f3edf5;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row5_col3 {
#             background-color:  #e0dded;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row5_col4 {
#             background-color:  #e9e5f1;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row5_col5 {
#             background-color:  #e3e0ee;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row6_col1 {
#             background-color:  #d7d6e9;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row6_col2 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row6_col3 {
#             background-color:  #a8bedc;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row6_col4 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row6_col5 {
#             background-color:  #e9e5f1;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row7_col1 {
#             background-color:  #d7d6e9;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row7_col2 {
#             background-color:  #e0deed;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row7_col3 {
#             background-color:  #fcf4fa;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row7_col4 {
#             background-color:  #3790c0;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row7_col5 {
#             background-color:  #e9e5f1;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row8_col1 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row8_col2 {
#             background-color:  #f9f2f8;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row8_col3 {
#             background-color:  #e7e3f0;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row8_col4 {
#             background-color:  #f8f1f8;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row8_col5 {
#             background-color:  #fdf5fa;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row9_col1 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row9_col2 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row9_col3 {
#             background-color:  #fff7fb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row9_col4 {
#             background-color:  #2685bb;
#         }    #T_78139c64_4c8d_11e8_a726_3464a92898c5row9_col5 {
#             background-color:  #fff7fb;
#         }</style>
# <table id="T_78139c64_4c8d_11e8_a726_3464a92898c5" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >country</th>
#         <th class="col_heading level0 col1" >points</th>
#         <th class="col_heading level0 col2" >count</th>
#         <th class="col_heading level0 col3" >min</th>
#         <th class="col_heading level0 col4" >max</th>
#         <th class="col_heading level0 col5" >mean</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_78139c64_4c8d_11e8_a726_3464a92898c5level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col0" class="data row0 col0" >Germany</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col1" class="data row0 col1" >98</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col2" class="data row0 col2" >1</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col3" class="data row0 col3" >775</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col4" class="data row0 col4" >775</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row0_col5" class="data row0 col5" >775</td>
#     </tr>    <tr>
#         <th id="T_78139c64_4c8d_11e8_a726_3464a92898c5level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col0" class="data row1 col0" >France</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col1" class="data row1 col1" >100</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col2" class="data row1 col2" >8</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col3" class="data row1 col3" >150</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col4" class="data row1 col4" >1500</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row1_col5" class="data row1 col5" >685.375</td>
#     </tr>    <tr>
#         <th id="T_78139c64_4c8d_11e8_a726_3464a92898c5level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col0" class="data row2 col0" >Australia</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col1" class="data row2 col1" >99</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col2" class="data row2 col2" >2</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col3" class="data row2 col3" >300</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col4" class="data row2 col4" >850</td>
#         <td id="T_78139c64_4c8d_11e8_a726_3464a92898c5row2_col5" class="data row2 col5" >575</td>
#     </tr>    <tr>
#         <th id="T_78139c64_4c8d_11e8_a726_3464a92898c5level0_row3" class="row_heading level0 row3" >3<

# %%
wine['points'].value_counts().sort_index().plot.bar(color = 'mediumvioletred',
                                                   title = 'Rankings given by winr magazine');

# %% [markdown]
# # Exploring the wine representation per country
#
# How many countries are represented?

# %%
wine['country'].nunique()
# Out:
# 43

# %% [markdown]
# Countries with the most wine representations

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize = (10, 8))
country = wine['country'].value_counts().to_frame()[0:20]
country.plot.bar(ax = ax, legend = None, title = ' Countries with most wine representations');

# %% [markdown]
# Which countries have the highest point mean?

# %%
country_grouped = wine.groupby('country')
grouped_list = country_grouped['points'].mean().reset_index()
grouped_list.sort_values(by ='points', ascending = False).iloc[:20].reset_index(drop = True)
# Out:
#          country     points
# 0        England  91.581081
# 1          India  90.222222
# 2        Austria  90.101345
# 3        Germany  89.851732
# 4         Canada  89.369650
# 5        Hungary  89.191781
# 6          China  89.000000
# 7         France  88.845109
# 8     Luxembourg  88.666667
# 9      Australia  88.580507
# 10   Switzerland  88.571429
# 11       Morocco  88.571429
# 12            US  88.563720
# 13         Italy  88.562231
# 14        Israel  88.471287
# 15   New Zealand  88.303030
# 16      Portugal  88.250220
# 17        Turkey  88.088889
# 18      Slovenia  88.068966
# 19  South Africa  88.056388

# %% [markdown]
# ## Getting only the wines produced by Chile

# %%
chile = wine[wine['country'] == 'Chile'].copy()
chile.head()
# Out:
#     Unnamed: 0 country                                        description  \
# 36          36   Chile  White flower, lychee and apple aromas carry th...
# 44          44   Chile  A berry aroma comes with cola and herb notes. ...
# 51          51   Chile  This is much different than Casa Silva's 2009 ...
# 58          58   Chile  Lightly herbal strawberry and raspberry aromas...
# 80          80   Chile  Caramelized oak and vanilla aromas are front a...
#
#                 designation  points  price          province region_1  \
# 36                   Estate      86   15.0  Colchagua Valley      NaN
# 44                      NaN      86    9.0      Maule Valley      NaN
# 51             Gran Reserva      85   22.0  Colchagua Valley      NaN
# 58                  Reserve      85   13.0      Maipo Valley      NaN
# 80  Special Release Reserva      86   12.0      Rapel Valley      NaN
#
#    region_2        taster_name taster_twitter_handle  \
# 36      NaN  Michael Schachner           @wineschach
# 44      NaN  Michael Schachner           @wineschach
# 51      NaN  Michael Schachner           @wineschach
# 58      NaN  Michael Schachner           @wineschach
# 80      NaN  Michael Schachner           @wineschach
#
#                                                 title              variety  \
# 36  Estampa 2011 Estate Viognier-Chardonnay (Colch...  Viognier-Chardonnay
# 44                Sundance 2011 Merlot (Maule Valley)               Merlot
# 51  Casa Silva 2008 Gran Reserva Petit Verdot (Col...         Petit Verdot
# 58  Tres Palacios 2011 Reserve Pinot Noir (Maipo V...           Pinot Noir
# 80  Aresti 2014 Special Release Reserva Carmenère ...            Carmenère
#
#            winery
# 36        Estampa
# 44       Sundance
# 51     Casa Silva
# 58  Tres Palacios
# 80         Aresti

# %%
fig, ax = plt.subplots(figsize = (10, 8))
chile_points = chile['points'].value_counts().to_frame()
chile_points.sort_values(by = 'points', ascending = False, inplace = True)
chile_points.plot.bar(ax = ax, legend = None)
ax.set_xlabel('Points')
ax.set_ylabel('No of wines');
